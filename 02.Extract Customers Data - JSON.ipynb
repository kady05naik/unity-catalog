-- %% [markdown]
-- ### Extract Data from Customers JSON file
-- 1. Query Single File
-- 2. Query list of files using wildcard characters
-- 3. Query all the files in a folder

-- %%
%fs ls /Volumes/gizmobox/landing/operational_data/customers/
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ### 1. Query single JSON file

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/customers_2024_10.json`
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ### 2. Query list of files using wildcard characters

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/customers_2024*.json`
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ### 3. Query all the files in a folder

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ### 4. Select _metadata

-- %%
SELECT 
    _metadata,
    *
from json.`/Volumes/gizmobox/landing/operational_data/customers/`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ### 5. Selecting file_path from metadata

-- %%
SELECT 
    _metadata.file_path AS file_path, 
    *
FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ### 6. Register files in Unity Catalog using Views

-- %%
CREATE OR REPLACE VIEW gizmobox.bronze.view_customers AS
    SELECT 
        _metadata.file_path AS file_path,
        *
    FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`;

-- %%
SELECT * FROM gizmobox.bronze.view_customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ### 7. Create temporary view

-- %%
CREATE OR REPLACE TEMPORARY VIEW temp_customers AS
    SELECT 
        _metadata.file_path AS file_path,
        *
    FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`;

-- %%
SELECT * FROM temp_customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
DESCRIBE EXTENDED temp_customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>file_path</td><td>string</td><td>null</td></tr><tr><td>created_timestamp</td><td>string</td><td>null</td></tr><tr><td>customer_id</td><td>bigint</td><td>null</td></tr><tr><td>customer_name</td><td>string</td><td>null</td></tr><tr><td>date_of_birth</td><td>string</td><td>null</td></tr><tr><td>email</td><td>string</td><td>null</td></tr><tr><td>member_since</td><td>string</td><td>null</td></tr><tr><td>telephone</td><td>string</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 8. Create Global View

-- %%
CREATE OR REPLACE GLOBAL TEMPORARY VIEW globTempView_customers AS
    SELECT 
        *,
        _metadata.file_path AS file_path
    FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`;
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-5847836026811896>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE OR REPLACE GLOBAL TEMPORARY VIEW globTempView_customers AS\n    SELECT \n        *,\n        _metadata.file_path AS file_path\n    FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`;\n')
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
-- ...

-- %%
SELECT * FROM global_temp.globTempView_customers;
